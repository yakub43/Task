# %% [markdown]
# <a href="https://colab.research.google.com/github/yakub43/Task/blob/main/Machine_Hack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("submission.csv")
# Out:
#         AQI_Bucket
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 212358           0
# 212359           0
# 212360           0
# 212361           0
# 212362           0
#
# [212363 rows x 1 columns]

# %%
pd.read_csv("test.csv")
# Out:
#            City             Datetime  PM2.5   PM10     NO   NO2   NOx   NH3  \
# 0      Shillong  2019-11-02 02:00:00   67.6  119.1   17.4  28.9  32.3  23.6
# 1         Patna  2019-11-27 11:00:00  265.0  119.1   34.0  38.7  48.2  23.6
# 2         Patna  2020-01-06 01:00:00   86.3  117.4   19.1  20.3  38.7  30.1
# 3      Shillong  2020-01-18 08:00:00   10.5   13.3    0.8   2.4   1.0   2.5
# 4         Delhi  2020-02-17 14:00:00   82.9  158.7   11.8  36.7  31.0  36.7
# ...         ...                  ...    ...    ...    ...   ...   ...   ...
# 37613    Mumbai  2017-04-30 05:00:00   67.6  119.1   17.4  28.9  32.3  23.6
# 37614   Lucknow  2018-01-21 05:00:00  181.8  119.1   17.0  39.0  33.9  52.2
# 37615     Kochi  2020-02-24 14:00:00   41.4  109.0    3.8  36.6  17.1   7.8
# 37616     Kochi  2020-03-04 22:00:00   40.5  132.2  105.2  28.9  81.2   2.4
# 37617   Chennai  2019-08-30 15:00:00   13.7   23.7    6.2   NaN   NaN   NaN
#
#         CO   SO2    O3  Benzene  Toluene  Xylene
# ...

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#         City             Datetime  PM2.5   PM10    NO   NO2   NOx   NH3   CO  \
# 0     Jaipur  2019-05-04 01:00:00   60.8   91.5  41.6  37.3  66.7  27.0  1.0
# 1   Amritsar  2017-04-27 19:00:00   23.8  119.1  14.9  17.1   NaN  28.4  0.0
# 2  Amaravati  2018-11-12 10:00:00   93.8  182.0   5.5  63.9   NaN   1.8  1.3
# 3      Kochi  2020-06-19 09:00:00   16.0   26.9  17.4   0.9   0.0  23.6  1.6
# 4  Ahmedabad  2019-05-16 03:00:00   29.5  138.4   NaN  31.6  26.0  23.6  9.3
#
#     SO2    O3  Benzene  Toluene  Xylene  AQI_Bucket
# 0  10.5  26.9      2.0      7.6     3.1         5.0
# 1   6.7  19.1      3.1      8.7     3.1         5.0
# 2  23.1  41.7      0.1      0.6     3.1         5.0
# 3  27.4  34.8      3.1      0.0     3.1         5.0
# 4   NaN  36.9     14.5     86.8    11.5         1.0

# %%
df['City']
# Out:
# 0             Jaipur
# 1           Amritsar
# 2          Amaravati
# 3              Kochi
# 4          Ahmedabad
#              ...
# 269350    Jorapokhar
# 269351        Mumbai
# 269352     Hyderabad
# 269353     Bengaluru
# 269354        Visakh
# Name: City, Length: 269355, dtype: object

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#         City             Datetime  PM2.5   PM10    NO   NO2   NOx   NH3   CO  \
# 0     Jaipur  2019-05-04 01:00:00   60.8   91.5  41.6  37.3  66.7  27.0  1.0
# 1   Amritsar  2017-04-27 19:00:00   23.8  119.1  14.9  17.1   NaN  28.4  0.0
# 2  Amaravati  2018-11-12 10:00:00   93.8  182.0   5.5  63.9   NaN   1.8  1.3
# 3      Kochi  2020-06-19 09:00:00   16.0   26.9  17.4   0.9   0.0  23.6  1.6
# 4  Ahmedabad  2019-05-16 03:00:00   29.5  138.4   NaN  31.6  26.0  23.6  9.3
#
#     SO2    O3  Benzene  Toluene  Xylene  AQI_Bucket
# 0  10.5  26.9      2.0      7.6     3.1         5.0
# 1   6.7  19.1      3.1      8.7     3.1         5.0
# 2  23.1  41.7      0.1      0.6     3.1         5.0
# 3  27.4  34.8      3.1      0.0     3.1         5.0
# 4   NaN  36.9     14.5     86.8    11.5         1.0

# %%
df.shape
# Out:
# (24490, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24490 entries, 0 to 24489
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        24490 non-null  object
#  1   Datetime    24490 non-null  object
#  2   PM2.5       24139 non-null  float64
#  3   PM10        23904 non-null  float64
#  4   NO          23207 non-null  float64
#  5   NO2         24198 non-null  float64
#  6   NOx         24026 non-null  float64
#  7   NH3         23438 non-null  float64
#  8   CO          24239 non-null  float64
#  9   SO2         23894 non-null  float64
#  10  O3          23369 non-null  float64
#  11  Benzene     24112 non-null  float64
#  12  Toluene     23940 non-null  float64
#  13  Xylene      23891 non-null  float64
#  14  AQI_Bucket  24489 non-null  float64
# dtypes: float64(13), object(2)
# memory usage: 2.8+ MB

# %%
df.isnull().sum()
# Out:
# City             0
# Datetime         0
# PM2.5          351
# PM10           586
# NO            1283
# NO2            292
# NOx            464
# NH3           1052
# CO             251
# SO2            596
# O3            1121
# Benzene        378
# Toluene        550
# Xylene         599
# AQI_Bucket       1
# dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# City          0.000000
# Datetime      0.000000
# PM2.5         1.433238
# PM10          2.392813
# NO            5.238873
# NO2           1.192323
# NOx           1.894651
# NH3           4.295631
# CO            1.024908
# SO2           2.433646
# O3            4.577379
# Benzene       1.543487
# Toluene       2.245815
# Xylene        2.445896
# AQI_Bucket    0.004083
# dtype: float64

# %%
df.describe().T
# Out:
#               count        mean        std  min   25%    50%    75%     max
# PM2.5       24139.0   67.689067  68.581046  0.0  30.8   60.0   67.6  1000.0
# PM10        23904.0  118.244470  77.722040  0.0  79.9  119.1  119.1  1000.0
# NO          23207.0   17.435166  29.729124  0.0   4.6    9.8   17.4   497.4
# NO2         24198.0   28.814671  27.235093  0.0  12.4   24.8   31.4   472.5
# NOx         24026.0   32.422946  36.528862  0.0  12.8   26.0   32.3   455.2
# NH3         23438.0   23.658973  22.388501  0.0  12.4   23.6   23.6   491.4
# CO          24239.0    2.378353  12.305113  0.0   0.5    0.9    2.0   446.4
# SO2         23894.0   13.977266  17.867282  0.0   5.5   10.5   14.0   199.1
# O3          23369.0   34.911614  27.197374  0.0  16.1   34.0   41.5   334.0
# Benzene     24112.0    3.006416  13.599150  0.0   0.2    1.8    3.1   484.4
# Toluene     23940.0    8.549365  18.058070  0.0   1.1    7.3    8.7   484.4
# ...

# %%
df.nunique()
# Out:
# City             26
# Datetime      18862
# PM2.5          2577
# PM10           3261
# NO             1342
# NO2            1419
# NOx            1739
# NH3            1171
# CO              469
# SO2            1029
# O3             1453
# Benzene         431
# Toluene         741
# Xylene          350
# AQI_Bucket        7
# dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Jaipur', 'Amritsar', 'Amaravati', 'Kochi', 'Ahmedabad', 'Lucknow',
#        'Thiruvananthapuram', 'Talcher', 'Guwahati', 'Delhi', 'Chandigarh',
#        'Visakhapatnam', 'Gurugram', 'Mumbai', 'Bengaluru', 'Coimbatore',
#        'Brajrajnagar', 'Hyderabad', 'Chennai', 'Patna', 'Kolkata',
#        'Bhopal', 'Jorapokhar', 'Aizawl', 'Shillong', 'Ernakulam'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI_Bucket'],
#       dtype='object')

# %%
sns.pairplot(data=df)

# %%
df['City'].value_counts()
# Out:
# Chennai               1795
# Ahmedabad             1697
# Hyderabad             1679
# Mumbai                1674
# Delhi                 1671
# Lucknow               1630
# Bengaluru             1615
# Patna                 1529
# Gurugram              1366
# Visakhapatnam         1190
# Amritsar              1031
# Jorapokhar             999
# Thiruvananthapuram     907
# Jaipur                 864
# Brajrajnagar           798
# Amaravati              761
# Talcher                748
# Kolkata                700
# Guwahati               390
# Coimbatore             364
# Shillong               247
# Bhopal                 241
# Chandigarh             225
# Ernakulam              147
# Kochi                  132
# Aizawl                  90
# Name: City, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
df.City.hist()
plt.xlabel('City')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='City', y='SO2', data=df)
# Out:
# <Axes: xlabel='City', ylabel='SO2'>

# %%
plt.rcParams['figure.figsize'] = (30,10)
df[['SO2','City']].groupby(['City']).mean().sort_values(by='SO2').plot.bar(color='Orange')
plt.show()

# %%
plt.xticks(rotation=90)
sns.barplot(x='City', y='NO2', data=df)
# Out:
# <Axes: xlabel='City', ylabel='NO2'>

# %%
df[['NO2','City']].groupby(['City']).mean().sort_values(by='NO2').plot.bar(color='Orange')
plt.show()
